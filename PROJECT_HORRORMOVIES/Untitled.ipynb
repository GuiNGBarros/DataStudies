# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt                                

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
dfilmes = pd.read_csv('horrormovies_cleaned.csv')

# %%
display(dfilmes)
# Out:
#                                                  Title  Release Year  \
# 0                         Das Cabinet des Dr. Caligari          1920
# 1                                London After Midnight          1927
# 2                                     West of Zanzibar          1928
# 3     Abbott and Costello Meet Dr. Jekyll and Mr. Hyde          1953
# 4                        The Beast from 20,000 Fathoms          1953
# ...                                                ...           ...
# 1155                                       Devil's Due          2014
# 1156                                        Sinister 2          2015
# 1157                                      Siksa Neraka          2023
# 1158                                Pee Mak Phrakanong          2013
# 1159                                               Boo          2023
#
#       Length in Min  IMDB Rating  Rating Count  \
# 0                76         8.00         70000
# ...

# %%
dfilmes.shape
# Out:
# (1160, 11)

# %%
dfilmes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1160 non-null   object
#  1   Release Year   1160 non-null   int64
#  2   Length in Min  1160 non-null   int64
#  3   IMDB Rating    1160 non-null   float64
#  4   Rating Count   1160 non-null   int64
#  5   Directors      1160 non-null   object
#  6   Writers        1154 non-null   object
#  7   Stars          1160 non-null   object
#  8   Genres         1160 non-null   object
#  9   Budget         1160 non-null   float64
#  10  Gross          1160 non-null   float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 99.8+ KB

# %%
dfilmes.describe()
# Out:
#        Release Year  Length in Min  IMDB Rating  Rating Count       Budget  \
# count       1160.00        1160.00      1160.00       1160.00      1160.00
# mean        2002.84          98.36         5.72      67366.32  13690208.73
# std           17.13          16.22         1.13     106281.26  20469284.76
# min         1920.00           0.00         2.10        101.00         1.00
# 25%         1992.00          89.00         5.00       7175.00   2000000.00
# 50%         2007.00          96.00         5.80      30000.00   6000100.00
# 75%         2016.00         105.00         6.50      82000.00  16000000.00
# max         2023.00         200.00         8.50    1100000.00 200000000.00
#
#              Gross
# count      1160.00
# mean   43520307.66
# std    77416850.79
# min           1.00
# 25%     1795412.50
# 50%    12664698.50
# 75%    50671850.00
# max   714766572.00

# %%
dfilmes.plot(kind = 'box', figsize = (25,8), subplots = True)
# Out:
# Release Year        Axes(0.125,0.11;0.110714x0.77)
# Length in Min    Axes(0.257857,0.11;0.110714x0.77)
# IMDB Rating      Axes(0.390714,0.11;0.110714x0.77)
# Rating Count     Axes(0.523571,0.11;0.110714x0.77)
# Budget           Axes(0.656429,0.11;0.110714x0.77)
# Gross            Axes(0.789286,0.11;0.110714x0.77)
# dtype: object

# %%
dfilmes[(dfilmes['Budget'] < 1000.00) | (dfilmes['Gross'] < 1000.00)| (dfilmes['Length in Min'] < 10)]
# Out:
# Empty DataFrame
# Columns: [Title, Release Year, Length in Min, IMDB Rating, Rating Count, Directors, Writers, Stars, Genres, Budget, Gross]
# Index: []

# %% [markdown]
# Estes filmes estão com problemas nos dados de orçamento, ou receita, ou duração.

# %%
len(dfilmes[(dfilmes['Budget'] < 1000.00) | (dfilmes['Gross'] < 1000.00)| (dfilmes['Length in Min'] < 10)])
# Out:
# 11

# %% [markdown]
# 11 filmes serão removidos do dataset

# %%
dfilmes = dfilmes[~((dfilmes['Budget'] < 1000.00) | 
                    (dfilmes['Gross'] < 1000.00)| 
                    (dfilmes['Length in Min'] < 10)|
                    (dfilmes['Gross']>710000000))]

# %%
dfilmes
# Out:
#                                                  Title  Release Year  \
# 0                         Das Cabinet des Dr. Caligari          1920
# 1                                London After Midnight          1927
# 2                                     West of Zanzibar          1928
# 3     Abbott and Costello Meet Dr. Jekyll and Mr. Hyde          1953
# 4                        The Beast from 20,000 Fathoms          1953
# ...                                                ...           ...
# 1155                                       Devil's Due          2014
# 1156                                        Sinister 2          2015
# 1157                                      Siksa Neraka          2023
# 1158                                Pee Mak Phrakanong          2013
# 1159                                               Boo          2023
#
#       Length in Min  IMDB Rating  Rating Count  \
# 0                76         8.00         70000
# ...

# %% [markdown]
# Verificando linhas duplicadas

# %%
linhas_duplicadas = dfilmes[dfilmes.duplicated()]
print("Linhas duplicadas:")
print(linhas_duplicadas)
# Out:
# Linhas duplicadas:
# Empty DataFrame
# Columns: [Title, Release Year, Length in Min, IMDB Rating, Rating Count, Directors, Writers, Stars, Genres, Budget, Gross]
# Index: []

# %%
num_duplicadas = dfilmes.duplicated().sum()
print("Número de linhas duplicadas:", num_duplicadas)
# Out:
# Número de linhas duplicadas: 0

# %%
dfilmes['Budget'] = dfilmes['Budget'].astype(int)
dfilmes['Gross'] = dfilmes['Gross'].astype(int)
# Out:
# C:\Users\Guilherme Barros\AppData\Local\Temp\ipykernel_15564\1687863473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfilmes['Budget'] = dfilmes['Budget'].astype(int)
# C:\Users\Guilherme Barros\AppData\Local\Temp\ipykernel_15564\1687863473.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfilmes['Gross'] = dfilmes['Gross'].astype(int)

# %%
dfilmes.to_csv('horrormovies.csv', index=True)

# %%
dfilmes[dfilmes['Title'] == "The Exorcist"]
# Out:
#             Title  Release Year  Length in Min  IMDB Rating  Rating Count  \
# 261  The Exorcist          1973            122         8.10        455000
#
#             Directors               Writers  \
# 261  William Friedkin  William Peter Blatty
#
#                                        Stars  Genres    Budget      Gross
# 261  Ellen Burstyn|Max von Sydow|Linda Blair  Horror  12000000  441306145
