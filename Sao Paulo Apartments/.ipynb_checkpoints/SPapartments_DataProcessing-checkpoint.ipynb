# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:.2f}'.format

# %%
apt = pd.read_csv('apartments_for_sale_sao_paulo.csv')

# %%
display(apt)
# Out:
#         registration_number  number       complement       neighborhood  \
# 0            17121501499.00  695.00    AP 94 E 2 VGS         VL ANDRADE
# 1             5101800457.00  503.00           CASA B          VILA BELA
# 2             6111300253.00  921.00              NaN                NaN
# 3             6902901351.00   17.00              NaN        V PAULICEIA
# 4            18312000312.00  100.00     CASA 16 E VG  RESID VILLA FIORE
# ...                     ...     ...              ...                ...
# 140896       11033800421.00  251.00           CASA 5                NaN
# 140897        2000302092.00  665.00            AP 84            TORRE A
# 140898       19603709033.00  300.00    AP 32 TORRE B         BELENZINHO
# 140899        4720802303.00  113.00   AP 12  E 2 VGS          JABAQUARA
# 140900        2106705417.00 1188.00  AP23/B134M/135M           PERDIZES
#
#         postal_code transaction_nature  transaction_value  \
# 0        5727230.00       buy_and_sell          720000.00
# 1        3144080.00       buy_and_sell          500000.00
# 2        3639000.00       buy_and_sell          410000.00
# 3        2302030.00       buy_and_sell          650000.00
# 4        5782470.00       buy_and_sell          413000.00
# ...             ...                ...                ...
# 140896   3671000.00       buy_and_sell          345000.00
# 140897   1137010.00       buy_and_sell         1450000.00
# 140898   3015010.00       buy_and_sell          400000.00
# 140899   4306090.00       buy_and_sell          784000.00
# 140900   5010000.00       buy_and_sell         1230000.00
#
#            transaction_date  built_area  \
# 0       2021-12-21 00:00:00      178.00
# 1       2021-12-21 00:00:00       65.00
# 2       2021-12-21 00:00:00      135.00
# 3       2021-12-27 00:00:00      119.00
# 4       2021-12-22 00:00:00       63.00
# ...                     ...         ...
# 140896  2023-07-28 00:00:00       60.00
# 140897  2023-07-31 00:00:00      239.00
# 140898  2023-06-30 00:00:00       88.00
# 140899  2023-06-29 00:00:00      154.00
# 140900  2023-08-01 00:00:00      174.00
#
#                                           use_description  \
# 0       Apartment in Condominium (Requires Ideal Fract...
# 1                                               Residence
# 2                                               Residence
# 3                                               Residence
# 4                                               Residence
# ...                                                   ...
# 140896                                          Residence
# 140897  Apartment in Condominium (Requires Ideal Fract...
# 140898  Apartment in Condominium (Requires Ideal Fract...
# 140899  Apartment in Condominium (Requires Ideal Fract...
# 140900  Apartment in Condominium (Requires Ideal Fract...
#
#         transmitted_proportion
# 0                       100.00
# 1                       100.00
# 2                       100.00
# 3                       100.00
# 4                       100.00
# ...                        ...
# 140896                  100.00
# 140897                  100.00
# 140898                  100.00
# 140899                  100.00
# 140900                  100.00
#
# [140901 rows x 11 columns]

# %%
apt.isnull().sum()
# Out:
# registration_number           0
# number                        0
# complement                22330
# neighborhood              48386
# postal_code                   0
# transaction_nature            0
# transaction_value             0
# transaction_date              0
# built_area                    0
# use_description               0
# transmitted_proportion        0
# dtype: int64

# %%
apt[['transaction_nature','use_description']].value_counts().to_frame() #Show in a df the number of rept of 
                                                                        # each variable value.
# Out:
#                                                                            0
# transaction_nature use_description
# buy_and_sell       Apartment in Condominium (Requires Ideal Fraction)  81701
#                    Residence                                           26562
#                    Garage (Autonomous Unit) in Residential Condomi...  10605
#                    Office/Clinic in Condominium (Autonomous Unit R...   6031
#                    Collective Residence, Exclusive Slum (More Than...   2849
#                    Land                                                 2358
#                    Commercial Use Flat (Similar to Hotel)               2330
#                    Store                                                1333
#                    Residence and Other Use (Residential Predominance)   1110
#                    Store and Residence (Commercial Predominance)         849
#                    Garage (Autonomous Unit) in Office, Clinic, or ...    812
#                    Office or Clinic Building, Not in Condominium, ...    801
#                    Store in Condominium Building (Autonomous Unit ...    687
#                    Other Buildings of the Type, with Multiple Use        615
#                    Residential Flat in Condominium (Requires Ideal...    383
#                    Hotel, Boarding House or Hostel                       340
#                    Industry                                              306
#                    Workshop                                              222
#                    General Warehouses and Depots                         210
#                    Garage (Autonomous Unit) in Garage Building (Re...    186
#                    School                                                143
#                    Garage (Exclusive in Condominium Building)             97
#                    Service Station                                        66
#                    Apartment Building, Not in Condominium, for Exc...     63
#                    Apartment Building, Not in Condominium, Mixed U...     61
#                    Temple                                                 37
#                    Hospital, Outpatient Clinic, Health Clinic and ...     31
#                    Unknown                                                29
#                    CORTIÇO (HABITAÇÃO COLETIVA SUBNORMAL)                 18
#                    ASILO, ORFANATO, CRECHE, SEMINÁRIO OU CONVENTO         17
#                    Other Buildings of the Type with Multiple Use          17
#                    Mixed-Use Building, Predominantly Non-Residenti...     12
#                    Radio Broadcasting Station, Television Station ...     10
#                    Cinema, Theater, Entertainment Venue, Club or S...     10

# %% [markdown]
# We must remove registration that has NaNs in df.

# %%
apt = apt.dropna()           # Removing NaNs.

# %%
apt.isnull().sum()           # NaNs removed.
# Out:
# registration_number       0
# number                    0
# complement                0
# neighborhood              0
# postal_code               0
# transaction_nature        0
# transaction_value         0
# transaction_date          0
# built_area                0
# use_description           0
# transmitted_proportion    0
# dtype: int64

# %%
apt[['transaction_value','built_area']].describe()
# Out:
#        transaction_value  built_area
# count           80544.00    80544.00
# mean           621924.87      128.13
# std           1382146.71      184.50
# min                 0.01        0.00
# 25%            220000.00       65.00
# 50%            350000.00       98.00
# 75%            638559.39      146.00
# max          84639423.71    17008.00

# %%
apt[['transaction_value','built_area']].plot(kind = 'box', figsize = (8,3), subplots = True)
# Out:
# transaction_value       Axes(0.125,0.11;0.352273x0.77)
# built_area           Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %% [markdown]
# At this point we have to filter the dataset removing all the rows that no contains 'Residence' in 'use_description' column.

# %%
apt = apt[apt['use_description'] == 'Residence']

# %%
display(apt)
# Out:
#         registration_number  number     complement       neighborhood  \
# 1             5101800457.00  503.00         CASA B          VILA BELA
# 4            18312000312.00  100.00   CASA 16 E VG  RESID VILLA FIORE
# 8            12409110699.00  155.00      CASA 16 A           PIRITUBA
# 28           10920000478.00  144.00    JD DA FONTE           TREMEMBE
# 33            5914000998.00  650.00       CASA  05            VILA RE
# ...                     ...     ...            ...                ...
# 140835       12209900432.00   10.00    LT 10B QD N        VL MARACANA
# 140841       17019401200.00  207.00          CS 13         CONDOMINIO
# 140848       11342700359.00   50.00          CS  3     VL. COPACABANA
# 140864        9515300134.00  423.00  LT 14 QD 47 A         INTERLAGOS
# 140879       11114400180.00    5.00     E 5 FUNDOS      ERM MATARAZZO
#
#         postal_code transaction_nature  transaction_value  \
# 1        3144080.00       buy_and_sell          500000.00
# 4        5782470.00       buy_and_sell          413000.00
# 8        5171600.00       buy_and_sell          380000.00
# 28       2355000.00       buy_and_sell         1050000.00
# 33       3662020.00       buy_and_sell          345000.00
# ...             ...                ...                ...
# 140835   5847500.00       buy_and_sell          660000.00
# 140841   5713570.00       buy_and_sell          690000.00
# 140848   3687170.00       buy_and_sell          375000.00
# 140864   4786035.00       buy_and_sell         1500000.00
# 140879   3894100.00       buy_and_sell          270000.00
#
#            transaction_date  built_area use_description  \
# 1       2021-12-21 00:00:00       65.00       Residence
# 4       2021-12-22 00:00:00       63.00       Residence
# 8       2021-12-22 00:00:00      178.00       Residence
# 28      2021-12-21 00:00:00      357.00       Residence
# 33      2021-12-23 00:00:00       60.00       Residence
# ...                     ...         ...             ...
# 140835  2023-07-12 00:00:00      208.00       Residence
# 140841  2023-07-21 00:00:00      214.00       Residence
# 140848  2023-07-24 00:00:00       68.00       Residence
# 140864  2023-07-31 00:00:00      308.00       Residence
# 140879  2023-08-02 00:00:00      104.00       Residence
#
#         transmitted_proportion
# 1                       100.00
# 4                       100.00
# 8                       100.00
# 28                      100.00
# 33                      100.00
# ...                        ...
# 140835                  100.00
# 140841                  100.00
# 140848                  100.00
# 140864                  100.00
# 140879                  100.00
#
# [6465 rows x 11 columns]

# %%
apt[['transaction_value','built_area']].describe()
# Out:
#        transaction_value  built_area
# count            6465.00     6465.00
# mean           620843.92      138.21
# std           1010448.01      120.88
# min                 0.01       17.00
# 25%            267535.00       72.00
# 50%            390000.00      107.00
# 75%            600000.00      159.00
# max          25400000.00     3295.00

# %%
apt[['transaction_value','built_area']].plot(kind = 'box', figsize = (8,3), subplots = True)
# Out:
# transaction_value       Axes(0.125,0.11;0.352273x0.77)
# built_area           Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %% [markdown]
# We must remove some outliers. Check max and min 'built_area' and 'transaction_value' variables.

# %%
apt = apt[~((apt['transaction_value'] < 10000.00)|      #I assume that the values in these 
    (apt['built_area'] < 5.00)|                         # conditionals are not reasonable values.
   (apt['built_area'] > 1000.00))]

# %%
apt[['transaction_value','built_area']].plot(kind = 'box', figsize = (8,3), subplots = True)
# Out:
# transaction_value       Axes(0.125,0.11;0.352273x0.77)
# built_area           Axes(0.547727,0.11;0.352273x0.77)
# dtype: object

# %%
display(apt)
# Out:
#         registration_number  number     complement       neighborhood  \
# 1             5101800457.00  503.00         CASA B          VILA BELA
# 4            18312000312.00  100.00   CASA 16 E VG  RESID VILLA FIORE
# 8            12409110699.00  155.00      CASA 16 A           PIRITUBA
# 28           10920000478.00  144.00    JD DA FONTE           TREMEMBE
# 33            5914000998.00  650.00       CASA  05            VILA RE
# ...                     ...     ...            ...                ...
# 140835       12209900432.00   10.00    LT 10B QD N        VL MARACANA
# 140841       17019401200.00  207.00          CS 13         CONDOMINIO
# 140848       11342700359.00   50.00          CS  3     VL. COPACABANA
# 140864        9515300134.00  423.00  LT 14 QD 47 A         INTERLAGOS
# 140879       11114400180.00    5.00     E 5 FUNDOS      ERM MATARAZZO
#
#         postal_code transaction_nature  transaction_value  \
# 1        3144080.00       buy_and_sell          500000.00
# 4        5782470.00       buy_and_sell          413000.00
# 8        5171600.00       buy_and_sell          380000.00
# 28       2355000.00       buy_and_sell         1050000.00
# 33       3662020.00       buy_and_sell          345000.00
# ...             ...                ...                ...
# 140835   5847500.00       buy_and_sell          660000.00
# 140841   5713570.00       buy_and_sell          690000.00
# 140848   3687170.00       buy_and_sell          375000.00
# 140864   4786035.00       buy_and_sell         1500000.00
# 140879   3894100.00       buy_and_sell          270000.00
#
#            transaction_date  built_area use_description  \
# 1       2021-12-21 00:00:00       65.00       Residence
# 4       2021-12-22 00:00:00       63.00       Residence
# 8       2021-12-22 00:00:00      178.00       Residence
# 28      2021-12-21 00:00:00      357.00       Residence
# 33      2021-12-23 00:00:00       60.00       Residence
# ...                     ...         ...             ...
# 140835  2023-07-12 00:00:00      208.00       Residence
# 140841  2023-07-21 00:00:00      214.00       Residence
# 140848  2023-07-24 00:00:00       68.00       Residence
# 140864  2023-07-31 00:00:00      308.00       Residence
# 140879  2023-08-02 00:00:00      104.00       Residence
#
#         transmitted_proportion
# 1                       100.00
# 4                       100.00
# 8                       100.00
# 28                      100.00
# 33                      100.00
# ...                        ...
# 140835                  100.00
# 140841                  100.00
# 140848                  100.00
# 140864                  100.00
# 140879                  100.00
#
# [6320 rows x 11 columns]

# %%
apt[apt.duplicated()]        # Checking for duplicate registration
# Out:
#         registration_number  number   complement    neighborhood  postal_code  \
# 4302         19213400046.00    4.00    QD G LT 4  ITAIM PAULISTA   8141620.00
# 131147       14827800153.00  108.00  JD CARVALHO       VILA RICA   3912270.00
# 134519       18513900094.00   73.00    LT 9 QD E       JD GUARAU   5544220.00
# 137441       14404202457.00 2381.00    CS 5 E VG  VILA CARMOSINA   8290001.00
#
#        transaction_nature  transaction_value     transaction_date  built_area  \
# 4302         buy_and_sell          112583.00  2022-01-26 00:00:00       60.00
# 131147       buy_and_sell          300000.00  2023-04-14 00:00:00       41.00
# 134519       buy_and_sell          420000.00  2023-06-29 00:00:00       70.00
# 137441       buy_and_sell          310000.00  2023-07-03 00:00:00       65.00
#
#        use_description  transmitted_proportion
# 4302         Residence                  100.00
# 131147       Residence                  100.00
# 134519       Residence                  100.00
# 137441       Residence                  100.00

# %%
apt = apt.drop_duplicates()

# %%
apt[apt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [registration_number, number, complement, neighborhood, postal_code, transaction_nature, transaction_value, transaction_date, built_area, use_description, transmitted_proportion]
# Index: []

# %%
apt['transaction_date'] = pd.to_datetime(apt['transaction_date'],    # converting the 'transaction_date' column 
                                         dayfirst = True)            # to a column of type 'datetime' to obtain 
                                                                     # the appropriate format.

# %%
apt.dtypes
# Out:
# registration_number              float64
# number                           float64
# complement                        object
# neighborhood                      object
# postal_code                      float64
# transaction_nature                object
# transaction_value                float64
# transaction_date          datetime64[ns]
# built_area                       float64
# use_description                   object
# transmitted_proportion           float64
# dtype: object

# %%
display(apt)
# Out:
#         registration_number  number     complement       neighborhood  \
# 1             5101800457.00  503.00         CASA B          VILA BELA
# 4            18312000312.00  100.00   CASA 16 E VG  RESID VILLA FIORE
# 8            12409110699.00  155.00      CASA 16 A           PIRITUBA
# 28           10920000478.00  144.00    JD DA FONTE           TREMEMBE
# 33            5914000998.00  650.00       CASA  05            VILA RE
# ...                     ...     ...            ...                ...
# 140835       12209900432.00   10.00    LT 10B QD N        VL MARACANA
# 140841       17019401200.00  207.00          CS 13         CONDOMINIO
# 140848       11342700359.00   50.00          CS  3     VL. COPACABANA
# 140864        9515300134.00  423.00  LT 14 QD 47 A         INTERLAGOS
# 140879       11114400180.00    5.00     E 5 FUNDOS      ERM MATARAZZO
#
#         postal_code transaction_nature  transaction_value transaction_date  \
# 1        3144080.00       buy_and_sell          500000.00       2021-12-21
# 4        5782470.00       buy_and_sell          413000.00       2021-12-22
# 8        5171600.00       buy_and_sell          380000.00       2021-12-22
# 28       2355000.00       buy_and_sell         1050000.00       2021-12-21
# 33       3662020.00       buy_and_sell          345000.00       2021-12-23
# ...             ...                ...                ...              ...
# 140835   5847500.00       buy_and_sell          660000.00       2023-07-12
# 140841   5713570.00       buy_and_sell          690000.00       2023-07-21
# 140848   3687170.00       buy_and_sell          375000.00       2023-07-24
# 140864   4786035.00       buy_and_sell         1500000.00       2023-07-31
# 140879   3894100.00       buy_and_sell          270000.00       2023-08-02
#
#         built_area use_description  transmitted_proportion
# 1            65.00       Residence                  100.00
# 4            63.00       Residence                  100.00
# 8           178.00       Residence                  100.00
# 28          357.00       Residence                  100.00
# 33           60.00       Residence                  100.00
# ...            ...             ...                     ...
# 140835      208.00       Residence                  100.00
# 140841      214.00       Residence                  100.00
# 140848       68.00       Residence                  100.00
# 140864      308.00       Residence                  100.00
# 140879      104.00       Residence                  100.00
#
# [6316 rows x 11 columns]

# %%
apt.drop(columns=['number', 'complement', 'transaction_nature','use_description','transmitted_proportion'], inplace=True)

# %%
display(apt)
# Out:
#         registration_number       neighborhood  postal_code  \
# 1             5101800457.00          VILA BELA   3144080.00
# 4            18312000312.00  RESID VILLA FIORE   5782470.00
# 8            12409110699.00           PIRITUBA   5171600.00
# 28           10920000478.00           TREMEMBE   2355000.00
# 33            5914000998.00            VILA RE   3662020.00
# ...                     ...                ...          ...
# 140835       12209900432.00        VL MARACANA   5847500.00
# 140841       17019401200.00         CONDOMINIO   5713570.00
# 140848       11342700359.00     VL. COPACABANA   3687170.00
# 140864        9515300134.00         INTERLAGOS   4786035.00
# 140879       11114400180.00      ERM MATARAZZO   3894100.00
#
#         transaction_value transaction_date  built_area
# 1               500000.00       2021-12-21       65.00
# 4               413000.00       2021-12-22       63.00
# 8               380000.00       2021-12-22      178.00
# 28             1050000.00       2021-12-21      357.00
# 33              345000.00       2021-12-23       60.00
# ...                   ...              ...         ...
# 140835          660000.00       2023-07-12      208.00
# 140841          690000.00       2023-07-21      214.00
# 140848          375000.00       2023-07-24       68.00
# 140864         1500000.00       2023-07-31      308.00
# 140879          270000.00       2023-08-02      104.00
#
# [6316 rows x 6 columns]

# %% [markdown]
# We have now to put the postal code into the format 'XXXX-XXX'

# %%
apt['postal_code'] = apt['postal_code'].astype(str).str.replace('.00', '', regex=False)  # Remove the '.00'
apt['postal_code'] = apt['postal_code'].str.replace(r'(\d{4})(\d{3})', r'\1-\2', regex=True)  # Formats as 'XXXX-XXX'

# %%
display(apt)
# Out:
#         registration_number       neighborhood postal_code  transaction_value  \
# 1             5101800457.00          VILA BELA    3144-080          500000.00
# 4            18312000312.00  RESID VILLA FIORE    5782-470          413000.00
# 8            12409110699.00           PIRITUBA    5171-600          380000.00
# 28           10920000478.00           TREMEMBE    2355-000         1050000.00
# 33            5914000998.00            VILA RE    3662-020          345000.00
# ...                     ...                ...         ...                ...
# 140835       12209900432.00        VL MARACANA    5847-500          660000.00
# 140841       17019401200.00         CONDOMINIO    5713-570          690000.00
# 140848       11342700359.00     VL. COPACABANA    3687-170          375000.00
# 140864        9515300134.00         INTERLAGOS    4786-035         1500000.00
# 140879       11114400180.00      ERM MATARAZZO    3894-100          270000.00
#
#        transaction_date  built_area
# 1            2021-12-21       65.00
# 4            2021-12-22       63.00
# 8            2021-12-22      178.00
# 28           2021-12-21      357.00
# 33           2021-12-23       60.00
# ...                 ...         ...
# 140835       2023-07-12      208.00
# 140841       2023-07-21      214.00
# 140848       2023-07-24       68.00
# 140864       2023-07-31      308.00
# 140879       2023-08-02      104.00
#
# [6316 rows x 6 columns]

# %%
apt['registration_number'] = apt['registration_number'].astype(str).str.replace('.00', '', regex=False)
apt[['transaction_value','built_area']] = apt[['transaction_value','built_area']].astype(int)

# %%
display(apt)
# Out:
#        registration_number       neighborhood postal_code  transaction_value  \
# 1               5101800457          VILA BELA    3144-080             500000
# 4              18312000312  RESID VILLA FIORE    5782-470             413000
# 8              12409110699           PIRITUBA    5171-600             380000
# 28             10920000478           TREMEMBE    2355-000            1050000
# 33              5914000998            VILA RE    3662-020             345000
# ...                    ...                ...         ...                ...
# 140835         12209900432        VL MARACANA    5847-500             660000
# 140841         17019401200         CONDOMINIO    5713-570             690000
# 140848         11342700359     VL. COPACABANA    3687-170             375000
# 140864          9515300134         INTERLAGOS    4786-035            1500000
# 140879         11114400180      ERM MATARAZZO    3894-100             270000
#
#        transaction_date  built_area
# 1            2021-12-21          65
# 4            2021-12-22          63
# 8            2021-12-22         178
# 28           2021-12-21         357
# 33           2021-12-23          60
# ...                 ...         ...
# 140835       2023-07-12         208
# 140841       2023-07-21         214
# 140848       2023-07-24          68
# 140864       2023-07-31         308
# 140879       2023-08-02         104
#
# [6316 rows x 6 columns]
