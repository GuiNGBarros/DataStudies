# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in d:\guibarros\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in d:\guibarros\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
# Imports
import pandas as pd
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
import time

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
# pd.options.display.float_format = '{:.2f}'.format

# %%
apt = pd.read_csv('apt_SP_cleaned.csv')

# %%
apt.head()
# Out:
#    registration_number postal_code  transaction_value transaction_date  \
# 0         5.101800e+09   03144-080             500000       2021-12-21
# 1         1.831200e+10   05782-470             413000       2021-12-22
# 2         1.240911e+10   05171-600             380000       2021-12-22
# 3         1.092000e+10   02355-000            1050000       2021-12-21
# 4         5.914001e+09   03662-020             345000       2021-12-23
#
#    built_area
# 0          65
# 1          63
# 2         178
# 3         357
# 4          60

# %%
apt.drop(columns = 'neighborhood', inplace = True)

# %%
geolocator = GoogleV3(api_key="API_KEY")

# %%
# Função para obter coordenadas e bairro a partir do CEP
def get_coordinates_from_cep(cep):
    try:
        location = geolocator.geocode(cep)
        if location:
            # Tenta extrair o bairro dos dados do endereço
            neighborhood = None
            for component in location.raw.get("address_components", []):
                if "sublocality" in component["types"]:
                    neighborhood = component["long_name"]
                    break
            return location.latitude, location.longitude, neighborhood
        else:
            return None, None, None
    except GeocoderTimedOut:
        print(f"Erro de timeout ao buscar dados para o CEP {cep}. Tentando novamente...")
        return get_coordinates_from_cep(cep)  # Tenta novamente em caso de timeout
    except Exception as e:
        print(f"Erro ao buscar dados para o CEP {cep}: {e}")
        return None, None, None

# %%
# Função para aplicar a geocodificação, exibir progresso e salvar o CSV a cada 50 requisições
def geocode_with_progress(row, index, total_rows, apt):
    latitude, longitude, neighborhood = get_coordinates_from_cep(row['postal_code'])
    if (index + 1) % 50 == 0:  # Exibe mensagem a cada 50 requisições
        print(f"Requisições concluídas: {index + 1} de {total_rows}")
        # Salva o dataframe em .csv a cada 50 requisições
        apt.to_csv(f'apt_progress_{index + 1}.csv', index=False)
        print(f"Arquivo salvo como 'apt_progress_{index + 1}.csv'")
    time.sleep(1)  # Atraso de 1 segundo entre requisições para evitar sobrecarga
    return latitude, longitude, neighborhood

# %%
# Aplicando a função para preencher as colunas de latitude, longitude e bairro
for index, row in apt.iterrows():
    latitude, longitude, neighborhood = geocode_with_progress(row, index, len(apt), apt)
    apt.at[index, 'latitude'] = latitude
    apt.at[index, 'longitude'] = longitude
    apt.at[index, 'neighborhood'] = neighborhood
# Out:
# Requisições concluídas: 50 de 6316
# Arquivo salvo como 'apt_progress_50.csv'
# Requisições concluídas: 100 de 6316
# Arquivo salvo como 'apt_progress_100.csv'
# Requisições concluídas: 150 de 6316
# Arquivo salvo como 'apt_progress_150.csv'
# Requisições concluídas: 200 de 6316
# Arquivo salvo como 'apt_progress_200.csv'
# Requisições concluídas: 250 de 6316
# Arquivo salvo como 'apt_progress_250.csv'
# Requisições concluídas: 300 de 6316
# Arquivo salvo como 'apt_progress_300.csv'
# Requisições concluídas: 350 de 6316
# Arquivo salvo como 'apt_progress_350.csv'
# Requisições concluídas: 400 de 6316
# Arquivo salvo como 'apt_progress_400.csv'
# Requisições concluídas: 450 de 6316
# Arquivo salvo como 'apt_progress_450.csv'
# Requisições concluídas: 500 de 6316
# Arquivo salvo como 'apt_progress_500.csv'
# Requisições concluídas: 550 de 6316
# Arquivo salvo como 'apt_progress_550.csv'
# Requisições concluídas: 600 de 6316
# Arquivo salvo como 'apt_progress_600.csv'
# Requisições concluídas: 650 de 6316
# Arquivo salvo como 'apt_progress_650.csv'
# Requisições concluídas: 700 de 6316
# Arquivo salvo como 'apt_progress_700.csv'
# Requisições concluídas: 750 de 6316
# Arquivo salvo como 'apt_progress_750.csv'
# Requisições concluídas: 800 de 6316
# Arquivo salvo como 'apt_progress_800.csv'
# Requisições concluídas: 850 de 6316
# Arquivo salvo como 'apt_progress_850.csv'
# Requisições concluídas: 900 de 6316
# Arquivo salvo como 'apt_progress_900.csv'
# Requisições concluídas: 950 de 6316
# Arquivo salvo como 'apt_progress_950.csv'
# Requisições concluídas: 1000 de 6316
# Arquivo salvo como 'apt_progress_1000.csv'
# Requisições concluídas: 1050 de 6316
# Arquivo salvo como 'apt_progress_1050.csv'
# Requisições concluídas: 1100 de 6316
# Arquivo salvo como 'apt_progress_1100.csv'
# Requisições concluídas: 1150 de 6316
# Arquivo salvo como 'apt_progress_1150.csv'
# Requisições concluídas: 1200 de 6316
# Arquivo salvo como 'apt_progress_1200.csv'
# Requisições concluídas: 1250 de 6316
# Arquivo salvo como 'apt_progress_1250.csv'
# Requisições concluídas: 1300 de 6316
# Arquivo salvo como 'apt_progress_1300.csv'
# Requisições concluídas: 1350 de 6316
# Arquivo salvo como 'apt_progress_1350.csv'
# Requisições concluídas: 1400 de 6316
# Arquivo salvo como 'apt_progress_1400.csv'
# Requisições concluídas: 1450 de 6316
# Arquivo salvo como 'apt_progress_1450.csv'
# Requisições concluídas: 1500 de 6316
# Arquivo salvo como 'apt_progress_1500.csv'
# Requisições concluídas: 1550 de 6316
# Arquivo salvo como 'apt_progress_1550.csv'
# Requisições concluídas: 1600 de 6316
# Arquivo salvo como 'apt_progress_1600.csv'
# Requisições concluídas: 1650 de 6316
# Arquivo salvo como 'apt_progress_1650.csv'
# Requisições concluídas: 1700 de 6316
# Arquivo salvo como 'apt_progress_1700.csv'
# Requisições concluídas: 1750 de 6316
# Arquivo salvo como 'apt_progress_1750.csv'
# Requisições concluídas: 1800 de 6316
# Arquivo salvo como 'apt_progress_1800.csv'
# Requisições concluídas: 1850 de 6316
# Arquivo salvo como 'apt_progress_1850.csv'
# Requisições concluídas: 1900 de 6316
# Arquivo salvo como 'apt_progress_1900.csv'
# Requisições concluídas: 1950 de 6316
# Arquivo salvo como 'apt_progress_1950.csv'
# Requisições concluídas: 2000 de 6316
# Arquivo salvo como 'apt_progress_2000.csv'
# Requisições concluídas: 2050 de 6316
# Arquivo salvo como 'apt_progress_2050.csv'
# Requisições concluídas: 2100 de 6316
# Arquivo salvo como 'apt_progress_2100.csv'
# Requisições concluídas: 2150 de 6316
# Arquivo salvo como 'apt_progress_2150.csv'
# Requisições concluídas: 2200 de 6316
# Arquivo salvo como 'apt_progress_2200.csv'
# Requisições concluídas: 2250 de 6316
# Arquivo salvo como 'apt_progress_2250.csv'
# Requisições concluídas: 2300 de 6316
# Arquivo salvo como 'apt_progress_2300.csv'
# Requisições concluídas: 2350 de 6316
# Arquivo salvo como 'apt_progress_2350.csv'
# Requisições concluídas: 2400 de 6316
# Arquivo salvo como 'apt_progress_2400.csv'
# Requisições concluídas: 2450 de 6316
# Arquivo salvo como 'apt_progress_2450.csv'
# Requisições concluídas: 2500 de 6316
# Arquivo salvo como 'apt_progress_2500.csv'
# Requisições concluídas: 2550 de 6316
# Arquivo salvo como 'apt_progress_2550.csv'
# Requisições concluídas: 2600 de 6316
# Arquivo salvo como 'apt_progress_2600.csv'
# Requisições concluídas: 2650 de 6316
# Arquivo salvo como 'apt_progress_2650.csv'
# Requisições concluídas: 2700 de 6316
# Arquivo salvo como 'apt_progress_2700.csv'
# Requisições concluídas: 2750 de 6316
# Arquivo salvo como 'apt_progress_2750.csv'
# Requisições concluídas: 2800 de 6316
# Arquivo salvo como 'apt_progress_2800.csv'
# Requisições concluídas: 2850 de 6316
# Arquivo salvo como 'apt_progress_2850.csv'
# Requisições concluídas: 2900 de 6316
# Arquivo salvo como 'apt_progress_2900.csv'
# Requisições concluídas: 2950 de 6316
# Arquivo salvo como 'apt_progress_2950.csv'
# Requisições concluídas: 3000 de 6316
# Arquivo salvo como 'apt_progress_3000.csv'
# Requisições concluídas: 3050 de 6316
# Arquivo salvo como 'apt_progress_3050.csv'
# Requisições concluídas: 3100 de 6316
# Arquivo salvo como 'apt_progress_3100.csv'
# Requisições concluídas: 3150 de 6316
# Arquivo salvo como 'apt_progress_3150.csv'
# Requisições concluídas: 3200 de 6316
# Arquivo salvo como 'apt_progress_3200.csv'
# Requisições concluídas: 3250 de 6316
# Arquivo salvo como 'apt_progress_3250.csv'
# Requisições concluídas: 3300 de 6316
# Arquivo salvo como 'apt_progress_3300.csv'
# Requisições concluídas: 3350 de 6316
# Arquivo salvo como 'apt_progress_3350.csv'
# Requisições concluídas: 3400 de 6316
# Arquivo salvo como 'apt_progress_3400.csv'
# Requisições concluídas: 3450 de 6316
# Arquivo salvo como 'apt_progress_3450.csv'
# Requisições concluídas: 3500 de 6316
# Arquivo salvo como 'apt_progress_3500.csv'
# Requisições concluídas: 3550 de 6316
# Arquivo salvo como 'apt_progress_3550.csv'
# Requisições concluídas: 3600 de 6316
# Arquivo salvo como 'apt_progress_3600.csv'
# Requisições concluídas: 3650 de 6316
# Arquivo salvo como 'apt_progress_3650.csv'
# Requisições concluídas: 3700 de 6316
# Arquivo salvo como 'apt_progress_3700.csv'
# Requisições concluídas: 3750 de 6316
# Arquivo salvo como 'apt_progress_3750.csv'
# Requisições concluídas: 3800 de 6316
# Arquivo salvo como 'apt_progress_3800.csv'
# Requisições concluídas: 3850 de 6316
# Arquivo salvo como 'apt_progress_3850.csv'
# Requisições concluídas: 3900 de 6316
# Arquivo salvo como 'apt_progress_3900.csv'
# Requisições concluídas: 3950 de 6316
# Arquivo salvo como 'apt_progress_3950.csv'
# Requisições concluídas: 4000 de 6316
# Arquivo salvo como 'apt_progress_4000.csv'
# Requisições concluídas: 4050 de 6316
# Arquivo salvo como 'apt_progress_4050.csv'
# Requisições concluídas: 4100 de 6316
# Arquivo salvo como 'apt_progress_4100.csv'
# Requisições concluídas: 4150 de 6316
# Arquivo salvo como 'apt_progress_4150.csv'
# Requisições concluídas: 4200 de 6316
# Arquivo salvo como 'apt_progress_4200.csv'
# Requisições concluídas: 4250 de 6316
# Arquivo salvo como 'apt_progress_4250.csv'
# Requisições concluídas: 4300 de 6316
# Arquivo salvo como 'apt_progress_4300.csv'
# Requisições concluídas: 4350 de 6316
# Arquivo salvo como 'apt_progress_4350.csv'
# Requisições concluídas: 4400 de 6316
# Arquivo salvo como 'apt_progress_4400.csv'
# Requisições concluídas: 4450 de 6316
# Arquivo salvo como 'apt_progress_4450.csv'
# Requisições concluídas: 4500 de 6316
# Arquivo salvo como 'apt_progress_4500.csv'
# Requisições concluídas: 4550 de 6316
# Arquivo salvo como 'apt_progress_4550.csv'
# Requisições concluídas: 4600 de 6316
# Arquivo salvo como 'apt_progress_4600.csv'
# Requisições concluídas: 4650 de 6316
# Arquivo salvo como 'apt_progress_4650.csv'
# Requisições concluídas: 4700 de 6316
# Arquivo salvo como 'apt_progress_4700.csv'
# Requisições concluídas: 4750 de 6316
# Arquivo salvo como 'apt_progress_4750.csv'
# Requisições concluídas: 4800 de 6316
# Arquivo salvo como 'apt_progress_4800.csv'
# Requisições concluídas: 4850 de 6316
# Arquivo salvo como 'apt_progress_4850.csv'
# Requisições concluídas: 4900 de 6316
# Arquivo salvo como 'apt_progress_4900.csv'
# Requisições concluídas: 4950 de 6316
# Arquivo salvo como 'apt_progress_4950.csv'
# Requisições concluídas: 5000 de 6316
# Arquivo salvo como 'apt_progress_5000.csv'
# Requisições concluídas: 5050 de 6316
# Arquivo salvo como 'apt_progress_5050.csv'
# Requisições concluídas: 5100 de 6316
# Arquivo salvo como 'apt_progress_5100.csv'
# Requisições concluídas: 5150 de 6316
# Arquivo salvo como 'apt_progress_5150.csv'
# Requisições concluídas: 5200 de 6316
# Arquivo salvo como 'apt_progress_5200.csv'
# Requisições concluídas: 5250 de 6316
# Arquivo salvo como 'apt_progress_5250.csv'
# Requisições concluídas: 5300 de 6316
# Arquivo salvo como 'apt_progress_5300.csv'
# Requisições concluídas: 5350 de 6316
# Arquivo salvo como 'apt_progress_5350.csv'
# Requisições concluídas: 5400 de 6316
# Arquivo salvo como 'apt_progress_5400.csv'
# Requisições concluídas: 5450 de 6316
# Arquivo salvo como 'apt_progress_5450.csv'
# Requisições concluídas: 5500 de 6316
# Arquivo salvo como 'apt_progress_5500.csv'
# Requisições concluídas: 5550 de 6316
# Arquivo salvo como 'apt_progress_5550.csv'
# Requisições concluídas: 5600 de 6316
# Arquivo salvo como 'apt_progress_5600.csv'
# Requisições concluídas: 5650 de 6316
# Arquivo salvo como 'apt_progress_5650.csv'
# Requisições concluídas: 5700 de 6316
# Arquivo salvo como 'apt_progress_5700.csv'
# Requisições concluídas: 5750 de 6316
# Arquivo salvo como 'apt_progress_5750.csv'
# Requisições concluídas: 5800 de 6316
# Arquivo salvo como 'apt_progress_5800.csv'
# Requisições concluídas: 5850 de 6316
# Arquivo salvo como 'apt_progress_5850.csv'
# Requisições concluídas: 5900 de 6316
# Arquivo salvo como 'apt_progress_5900.csv'
# Requisições concluídas: 5950 de 6316
# Arquivo salvo como 'apt_progress_5950.csv'
# Requisições concluídas: 6000 de 6316
# Arquivo salvo como 'apt_progress_6000.csv'
# Requisições concluídas: 6050 de 6316
# Arquivo salvo como 'apt_progress_6050.csv'
# Requisições concluídas: 6100 de 6316
# Arquivo salvo como 'apt_progress_6100.csv'
# Requisições concluídas: 6150 de 6316
# Arquivo salvo como 'apt_progress_6150.csv'
# Requisições concluídas: 6200 de 6316
# Arquivo salvo como 'apt_progress_6200.csv'
# Requisições concluídas: 6250 de 6316
# Arquivo salvo como 'apt_progress_6250.csv'
# Requisições concluídas: 6300 de 6316
# Arquivo salvo como 'apt_progress_6300.csv'

# %%
apt.isna().sum()
# Out:
# registration_number      0
# postal_code              0
# transaction_value        0
# transaction_date         0
# built_area               0
# latitude               120
# longitude              120
# neighborhood           146
# dtype: int64

# %%
apt = apt.dropna()

# %%
apt.isna().sum()
# Out:
# registration_number    0
# postal_code            0
# transaction_value      0
# transaction_date       0
# built_area             0
# latitude               0
# longitude              0
# neighborhood           0
# dtype: int64

# %%
display(apt)
# Out:
#       registration_number postal_code  transaction_value transaction_date  \
# 0            5.101800e+09   03144-080             500000       2021-12-21
# 1            1.831200e+10   05782-470             413000       2021-12-22
# 2            1.240911e+10   05171-600             380000       2021-12-22
# 3            1.092000e+10   02355-000            1050000       2021-12-21
# 4            5.914001e+09   03662-020             345000       2021-12-23
# ...                   ...         ...                ...              ...
# 6311         1.220990e+10   05847-500             660000       2023-07-12
# 6312         1.701940e+10   05713-570             690000       2023-07-21
# 6313         1.134270e+10   03687-170             375000       2023-07-24
# 6314         9.515300e+09   04786-035            1500000       2023-07-31
# 6315         1.111440e+10   03894-100             270000       2023-08-02
#
#       built_area   latitude  longitude                      neighborhood
# 0             65 -23.596041 -46.574510                        Vila Lucia
# 1             63 -23.650386 -46.765836                     Parque Munhoz
# 2            178 -23.473614 -46.750166  Conjunto Residencial Vista Verde
# 3            357 -23.456164 -46.612475            Jardim Virginia Bianca
# 4             60 -23.522384 -46.497763                           Vila Ré
# ...          ...        ...        ...                               ...
# 6311         208 -23.652428 -46.748946                    Jardim Iracema
# 6312         214 -23.624770 -46.729349                  Jardim Ampliacao
# 6313          68 -23.525760 -46.486938                Jardim Artur Alvim
# 6314         308 -23.702521 -46.705402                        Interlagos
# 6315         104 -23.515513 -46.481701                 Jardim Ponte Rasa
#
# [6170 rows x 8 columns]

# %%
apt.to_csv('apt_SP_pointsadded.csv', index = False)
